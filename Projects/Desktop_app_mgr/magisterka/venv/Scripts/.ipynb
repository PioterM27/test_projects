# %%
import pandas
df=pandas.read_csv("D:\KursAI\python\pliki_kurs\diamonds_single.csv",sep=";",header=0)
df.head()
# Out:
#    price  carat
# 0    326   0.23
# 1    326   0.21
# 2    327   0.23
# 3    334   0.29
# 4    335   0.31

# %%
df.shape
# Out:
# (53940, 2)

# %%
# %matplotlib inline
df.plot.scatter(x='carat',y='price')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-3eb29414d71d> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 df.plot.scatter(x='carat',y='price')
#
# d:\kursai\python\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# <d:\kursai\python\lib\site-packages\decorator.py:decorator-gen-109> in matplotlib(self, line)
#
# d:\kursai\python\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...
