# %%
import pandas

# %%
df=pandas.read_csv("D:\KursAI\python\pliki_kurs\data-geo.csv",sep=",",header=0)

# %%
display(df)
# Out:
#      2014 rank                City       State State Code  \
# 0          101          Birmingham     Alabama         AL
# 1          125          Huntsville     Alabama         AL
# 2          122              Mobile     Alabama         AL
# 3          114          Montgomery     Alabama         AL
# 4           64       Anchorage[19]      Alaska         AK
# 5           78            Chandler     Arizona         AZ
# 6           86         Gilbert[20]     Arizona         AZ
# 7           88            Glendale     Arizona         AZ
# 8           38                Mesa     Arizona         AZ
# 9          148              Peoria     Arizona         AZ
# 10           6             Phoenix     Arizona         AZ
# 11          95          Scottsdale     Arizona         AZ
# 12         215            Surprise     Arizona         AZ
# 13         142               Tempe     Arizona         AZ
# 14          33              Tucson     Arizona         AZ
# ...

# %%
dir(pandas)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
df.head(5)
# Out:
#    2014 rank           City    State State Code  2014 Population estimate  \
# 0        101     Birmingham  Alabama         AL                  212247.0
# 1        125     Huntsville  Alabama         AL                  188226.0
# 2        122         Mobile  Alabama         AL                  194675.0
# 3        114     Montgomery  Alabama         AL                  200481.0
# 4         64  Anchorage[19]   Alaska         AK                  301010.0
#
#    2015 median sales price
# 0                    162.9
# 1                    157.7
# 2                    122.5
# 3                    129.0
# 4                      NaN

# %%
df.shape
# Out:
# (294, 6)

# %%
t=df.shape

# %%
t
# Out:
# (294, 6)

# %%
t[0]
# Out:
# 294

# %%
df['2014rank']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\kursai\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2014rank'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-78d2c62778d8> in <module>
# ----> 1 df['2014rank']
#
# ...

# %%
df[['City','State']]
# Out:
#                    City       State
# 0            Birmingham     Alabama
# 1            Huntsville     Alabama
# 2                Mobile     Alabama
# 3            Montgomery     Alabama
# 4         Anchorage[19]      Alaska
# 5              Chandler     Arizona
# 6           Gilbert[20]     Arizona
# 7              Glendale     Arizona
# 8                  Mesa     Arizona
# 9                Peoria     Arizona
# 10              Phoenix     Arizona
# 11           Scottsdale     Arizona
# 12             Surprise     Arizona
# 13                Tempe     Arizona
# 14               Tucson     Arizona
# 15          Little Rock    Arkansas
# 16              Anaheim  California
# 17              Antioch  California
# 18          Bakersfield  California
# 19             Berkeley  California
# 20              Burbank  California
# 21             Carlsbad  California
# 22          Chula Vista  California
# 23               Clovis  California
# 24              Concord  California
# ...

# %%
df[df['State']=="Texas"]
# Out:
#      2014 rank             City  State State Code  2014 Population estimate  \
# 237        221          Abilene  Texas         TX                  120958.0
# 238        120         Amarillo  Texas         TX                  197254.0
# 239         51        Arlington  Texas         TX                  383204.0
# 240         11           Austin  Texas         TX                  912791.0
# 241        230         Beaumont  Texas         TX                  117585.0
# 242        130      Brownsville  Texas         TX                  183046.0
# 243        207       Carrollton  Texas         TX                  128353.0
# 244        282  College Station  Texas         TX                  103483.0
# 245         58   Corpus Christi  Texas         TX                  320434.0
# 246          9           Dallas  Texas         TX                 1281047.0
# 247        209           Denton  Texas         TX                  128205.0
# ...

# %%
df.iloc[100]
# Out:
# 2014 rank                           198
# City                          New Haven
# State                       Connecticut
# State Code                           CT
# 2014 Population estimate         130282
# 2015 median sales price           205.1
# Name: 100, dtype: object

# %%
dir[df]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-b69da80acad1> in <module>
# ----> 1 dir[df]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
df["newcol"]="test"

# %%
df
# Out:
#      2014 rank                City       State State Code  \
# 0          101          Birmingham     Alabama         AL
# 1          125          Huntsville     Alabama         AL
# 2          122              Mobile     Alabama         AL
# 3          114          Montgomery     Alabama         AL
# 4           64       Anchorage[19]      Alaska         AK
# 5           78            Chandler     Arizona         AZ
# 6           86         Gilbert[20]     Arizona         AZ
# 7           88            Glendale     Arizona         AZ
# 8           38                Mesa     Arizona         AZ
# 9          148              Peoria     Arizona         AZ
# 10           6             Phoenix     Arizona         AZ
# 11          95          Scottsdale     Arizona         AZ
# 12         215            Surprise     Arizona         AZ
# 13         142               Tempe     Arizona         AZ
# 14          33              Tucson     Arizona         AZ
# ...

# %%
df.groupby(['State']).mean()
# Out:
#                        2014 rank  2014 Population estimate  \
# State
# Alabama               115.500000              1.989072e+05
# Alaska                 64.000000              3.010100e+05
# Arizona                92.900000              3.957341e+05
# Arkansas              119.000000              1.977060e+05
# California            164.563380              2.708884e+05
# Colorado              176.818182              2.223300e+05
# Connecticut           211.800000              1.280368e+05
# District of Columbia   22.000000              6.588930e+05
# Florida               164.095238              2.117851e+05
# Georgia               161.857143              2.032563e+05
# Hawai'i                55.000000              3.503990e+05
# Idaho                  99.000000              2.162820e+05
# Illinois              170.125000              4.637222e+05
# Indiana               104.666667              4.092187e+05
# Iowa                  199.000000              1.469543e+05
# ...

# %%
df.head()
# Out:
#    2014 rank           City    State State Code  2014 Population estimate  \
# 0        101     Birmingham  Alabama         AL                  212247.0
# 1        125     Huntsville  Alabama         AL                  188226.0
# 2        122         Mobile  Alabama         AL                  194675.0
# 3        114     Montgomery  Alabama         AL                  200481.0
# 4         64  Anchorage[19]   Alaska         AK                  301010.0
#
#    2015 median sales price newcol
# 0                    162.9   test
# 1                    157.7   test
# 2                    122.5   test
# 3                    129.0   test
# 4                      NaN   test

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-09616d73ed79> in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
len(df)
# Out:
# 294

# %%
df.shape
# Out:
# (294, 7)

# %%
df.values
# Out:
# array([[101, 'Birmingham', 'Alabama', ..., 212247.0, 162.9, 'test'],
#        [125, 'Huntsville', 'Alabama', ..., 188226.0, 157.7, 'test'],
#        [122, 'Mobile', 'Alabama', ..., 194675.0, 122.5, 'test'],
#        ...,
#        [279, 'Green Bay', 'Wisconsin', ..., 104891.0, nan, 'test'],
#        [83, 'Madison', 'Wisconsin', ..., 245691.0, 226.2, 'test'],
#        [31, 'Milwaukee', 'Wisconsin', ..., 599642.0, 195.4, 'test']],
#       dtype=object)

# %%
df.describe()
# Out:
#         2014 rank  2014 Population estimate  2015 median sales price
# count  294.000000              2.930000e+02               109.000000
# mean   147.500000              3.072849e+05               211.266055
# std     85.014705              6.034878e+05               134.017245
# min      1.000000              1.014080e+05                78.600000
# 25%     74.250000              1.209580e+05               141.100000
# 50%    147.500000              1.685860e+05               177.200000
# 75%    220.750000              2.621460e+05               218.900000
# max    294.000000              8.491079e+06               900.000000

# %%
df.col1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-2356b78d3ef1> in <module>
# ----> 1 df.col1
#
# d:\kursai\python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'col1'

# %%
df.State
# Out:
# 0         Alabama
# 1         Alabama
# 2         Alabama
# 3         Alabama
# 4          Alaska
# 5         Arizona
# 6         Arizona
# 7         Arizona
# 8         Arizona
# 9         Arizona
# 10        Arizona
# 11        Arizona
# 12        Arizona
# 13        Arizona
# 14        Arizona
# 15       Arkansas
# 16     California
# 17     California
# 18     California
# 19     California
# 20     California
# 21     California
# 22     California
# 23     California
# 24     California
# 25     California
# 26     California
# 27     California
# 28     California
# 29     California
#           ...
# 264         Texas
# 265         Texas
# 266         Texas
# 267         Texas
# 268         Texas
# 269         Texas
# 270         Texas
# 271         Texas
# 272         Texas
# 273          Utah
# 274          Utah
# 275          Utah
# 276          Utah
# 277      Virginia
# 278      Virginia
# 279      Virginia
# 280      Virginia
# 281      Virginia
# 282      Virginia
# ...
